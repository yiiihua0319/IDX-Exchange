# %% [markdown]
# #  Monthly Dataset Aggregation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import csv

# %% [markdown]
# ## Loading Data for Listing files from 202401 to 202603

# %%
listing1 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202401.csv')
listing2 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202402.csv')
listing3 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202403.csv')
listing4 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202404.csv')
listing5 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202405.csv')
listing6 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202406.csv') 
listing7 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202407.csv')
listing8 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202408.csv')
listing9 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202409.csv')
listing10 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202410.csv')
listing11 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202411.csv')
listing12 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202412.csv')   
listing13 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202501.csv')
listing14 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202502.csv')
listing15 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202503.csv')
listing16 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202504.csv')
listing17 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202505.csv')
listing18 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202506.csv') 
listing19 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202507.csv')
listing20 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202508.csv')
listing21 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202509.csv')
listing22 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202510.csv')
listing23 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202511.csv')
listing24 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202512.csv')
listing25 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202601.csv')
listing26 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202602.csv')
listing27 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSListing202603.csv')

# %% [markdown]
# concat all the files together

# %%
listing = pd.concat([listing1, listing2, listing3, listing4, listing5, listing6, listing7, listing8, listing9, listing10, listing11, listing12, listing13, listing14, listing15, listing16, listing17, listing18, listing19, listing20, listing21, listing22, listing23, listing24, listing25, listing26, listing27], ignore_index=True)

# %% [markdown]
# check the len of the listing

# %%
len(listing)
# Out:
# 852963

# %% [markdown]
# Filter the data for the PropertyType 'Residential'

# %%
res_listing = listing[listing['PropertyType'] == 'Residential']

# %% [markdown]
# Check the len of listing

# %%
len(res_listing)
# Out:
# 540183

# %%
res_listing.to_csv('/Users/huangyihua/Desktop/IDX-Exchange/res_listing.csv', index=False)

# %% [markdown]
# ## Loading Data for sold files from 20240 to 202603

# %%
sold1 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202401.csv')
sold2 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202402.csv')
sold3 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202403.csv')
sold4 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202404.csv')
sold5 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202405.csv')
sold6 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202406.csv') 
sold7 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202407.csv')
sold8 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202408.csv')
sold9 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202409.csv')
sold10 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202410.csv')
sold11 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202411.csv')
sold12 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202412.csv')   
sold13 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202501.csv')
sold14 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202502.csv')
sold15 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202503.csv')
sold16 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202504.csv')
sold17 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202505.csv')
sold18 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202506.csv') 
sold19 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202507.csv')
sold20 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202508.csv')
sold21 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202509.csv')
sold22 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202510.csv')
sold23 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202511.csv')
sold24 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202512.csv')
sold25 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202601.csv')
sold26 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202602.csv')
sold27 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202603.csv')
# Out:
# /var/folders/fb/y3cbnxzj3rs43kpb74nk2f0r0000gn/T/ipykernel_37506/2269952658.py:4: DtypeWarning: Columns (2,36,39,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold4 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202404.csv')
# /var/folders/fb/y3cbnxzj3rs43kpb74nk2f0r0000gn/T/ipykernel_37506/2269952658.py:18: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold18 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202506.csv')
# /var/folders/fb/y3cbnxzj3rs43kpb74nk2f0r0000gn/T/ipykernel_37506/2269952658.py:25: DtypeWarning: Columns (4,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold25 = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/Data/CRMLSSold202601.csv')

# %% [markdown]
# Concat files together

# %%
sold = pd.concat([sold1, sold2, sold3, sold4, sold5, sold6, sold7, sold8, sold9, sold10, sold11, sold12, sold13, sold14, sold15, sold16, sold17, sold18, sold19, sold20, sold21, sold22, sold23, sold24, sold25, sold26, sold27], ignore_index=True)

# %%
len(sold)
# Out:
# 591733

# %% [markdown]
# Filter the data for the PropertyType 'Residential'

# %%
res_sold = sold[sold['PropertyType'] == 'Residential']

# %%
len(res_sold)
# Out:
# 397603

# %%
res_sold.to_csv('/Users/huangyihua/Desktop/IDX-Exchange/res_sold.csv', index=False)
