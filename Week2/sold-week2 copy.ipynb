# %% [markdown]
# # Data Structuring and Validation

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Sold Data

# %%
sold = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/sold.csv')
# Out:
# /var/folders/fb/y3cbnxzj3rs43kpb74nk2f0r0000gn/T/ipykernel_13010/251396570.py:1: DtypeWarning: Columns (0,1,4,9,78,79,80,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold = pd.read_csv('/Users/huangyihua/Desktop/IDX-Exchange/sold.csv')

# %% [markdown]
# ## Dataset Understanding

# %%
pd.set_option('display.max_columns', None)
listing.head()
# Out:
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0            90000.0  1075010398                miriamlara03@gmail.com
# 1          1500000.0  1074974457                  janelle@judsonre.com
# 2          1340000.0  1074973329                    haleh360@Gmail.com
# 3          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 4          3150000.0  1074936537                      anader@dppre.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN             Miriam              Lara  34.097939
# 1       NaN         NaN            Janelle            Judson  33.121241
# 2       NaN         NaN              Haleh       Dowlatshahi  34.052207
# 3       NaN         NaN              Renee              Chen  33.496363
# 4       NaN         NaN           Margaret             Nader  34.119345
#
#     Longitude                UnparsedAddress        PropertyType  LivingArea  \
# 0 -117.909653                1045 N Azusa 61  ManufacturedInPark       960.0
# 1 -117.081614                            NaN      CommercialSale         NaN
# 2 -118.408445  2220 Avenue Of The Stars 2704         Residential      1301.0
# 3 -117.691677                   16 Palisades         Residential      2788.0
# 4 -118.111254              1615 Waverly Road         Residential      3250.0
#
#    ListPrice  DaysOnMarket                    ListOfficeName BuyerOfficeName  \
# 0    90000.0             0      CENTURY 21 CITRUS REALTY INC             NaN
# 1  1500000.0             0                Judson Real Estate             NaN
# 2  1340000.0           127           Rodeo Realty- Brentwood             NaN
# 3  2500000.0             1  Your Home Sold Guaranteed Realty             NaN
# 4  3150000.0             1                           COMPASS             NaN
#
#      CoListOfficeName  ListAgentFullName CoListAgentFirstName  \
# 0                 NaN        Miriam Lara                  NaN
# 1  Judson Real Estate     Janelle Judson                 Lynn
# 2                 NaN  Haleh Dowlatshahi                  NaN
# 3                 NaN         Renee Chen                  NaN
# 4                 NaN     Margaret Nader                  NaN
#
#   CoListAgentLastName BuyerAgentMlsId BuyerAgentFirstName BuyerAgentLastName  \
# 0                 NaN             NaN                 NaN                NaN
# 1              Judson             NaN                 NaN                NaN
# 2                 NaN             NaN                 NaN                NaN
# 3                 NaN             NaN                 NaN                NaN
# 4                 NaN             NaN                 NaN                NaN
#
#    FireplacesTotal AssociationFeeFrequency  AboveGradeFinishedArea  \
# 0              NaN                     NaN                     NaN
# 1              NaN                     NaN                     NaN
# 2              NaN                 Monthly                     NaN
# 3              NaN                 Monthly                     NaN
# 4              NaN                     NaN                     NaN
#
#    ListingKeyNumeric                   MLSAreaMajor  TaxAnnualAmount  \
# 0         1075010398                   614 - Covina              NaN
# 1         1074974457              92025 - Escondido              NaN
# 2         1074973329  C05 - Westwood - Century City              NaN
# 3         1074954552             LNSLT - Salt Creek              NaN
# 4         1074936537               655 - San Marino              NaN
#
#   CountyOrParish      PropertyType.1 MlsStatus ElementarySchool  \
# 0    Los Angeles  ManufacturedInPark    Active              NaN
# 1      San Diego      CommercialSale    Active              NaN
# 2    Los Angeles         Residential   Pending              NaN
# 3         Orange         Residential    Active              NaN
# 4    Los Angeles         Residential    Active              NaN
#
#   ListAgentFirstName.1 AttachedGarageYN  ParkingTotal BuilderName  \
# 0               Miriam            False           4.0         NaN
# 1              Janelle              NaN           0.0         NaN
# 2                Haleh              NaN           0.0         NaN
# 3                Renee             True           3.0         NaN
# 4             Margaret             True           2.0         NaN
#
#          PropertySubType  LotSizeAcres              SubdivisionName  \
# 0                    NaN           NaN                          NaN
# 1                 Retail           NaN                          NaN
# 2            Condominium        4.0831                          NaN
# 3  SingleFamilyResidence        0.1217  Warmington Homes (BB) (BBW)
# 4  SingleFamilyResidence        0.2159                          NaN
#
#   BuyerOfficeAOR  YearBuilt  DaysOnMarket.1 BuyerAgencyCompensationType  \
# 0            NaN     1960.0               0                        Item
# 1            NaN     1940.0               0                       Item1
# 2            NaN     1964.0             127                       Item1
# 3            NaN     1994.0               1                       Item1
# 4            NaN     1965.0               1                       Item1
#
#    StreetNumberNumeric  LivingArea.1   ListingId  BathroomsTotalInteger  \
# 0               1045.0         960.0  CV24093347                    1.0
# 1                  NaN           NaN  NDP2403932                    0.0
# 2               2220.0        1301.0    24389291                    2.0
# 3                 16.0        2788.0  AR24091628                    3.0
# 4               1615.0        3250.0    P1-17547                    4.0
#
#             City  BuyerAgencyCompensation  TaxYear  BuildingAreaTotal  \
# 0         Covina                   2500.0      NaN                NaN
# 1      Escondido                      2.0      NaN             3000.0
# 2    Los Angeles                      2.0      NaN             1301.0
# 3  Laguna Niguel                      2.0      NaN                NaN
# 4     San Marino                      2.5      NaN                NaN
#
#    BedroomsTotal ContractStatusChangeDate  Longitude.1  \
# 0            4.0               2024-01-29  -117.909653
# 1            NaN               2024-01-11  -117.081614
# 2            2.0               2024-05-07  -118.408445
# 3            4.0               2024-01-24  -117.691677
# 4            6.0               2024-01-12  -118.111254
#
#    ElementarySchoolDistrict CoBuyerAgentFirstName PurchaseContractDate  \
# 0                       NaN                   NaN                  NaN
# 1                       NaN                   NaN                  NaN
# 2                       NaN                   NaN           2024-05-07
# 3                       NaN                   NaN                  NaN
# 4                       NaN                   NaN                  NaN
#
#   ListingContractDate  BelowGradeFinishedArea BusinessType  Latitude.1  \
# 0          2024-01-29                     NaN          NaN   34.097939
# 1          2024-01-11                     NaN          NaN   33.121241
# 2          2024-01-01                     NaN          NaN   34.052207
# 3          2024-01-24                     NaN          NaN   33.496363
# 4          2024-01-12                     NaN          NaN   34.119345
#
#    ListPrice.1 StateOrProvince  CoveredSpaces MiddleOrJuniorSchool  \
# 0      90000.0              CA            NaN                  NaN
# 1    1500000.0              CA            NaN                  NaN
# 2    1340000.0              CA            NaN                  NaN
# 3    2500000.0              CA            NaN                  NaN
# 4    3150000.0              CA            NaN                  NaN
#
#   FireplaceYN  Stories HighSchool Levels ListAgentLastName.1 CloseDate.1  \
# 0         NaN      1.0        NaN    One                Lara         NaN
# 1         NaN      NaN        NaN    NaN              Judson         NaN
# 2       False      1.0        NaN    One         Dowlatshahi         NaN
# 3        True      2.0        NaN    Two                Chen         NaN
# 4        True      2.0        NaN    Two               Nader         NaN
#
#   LotSizeDimensions  LotSizeArea  MainLevelBedrooms NewConstructionYN  \
# 0               NaN          NaN                NaN               NaN
# 1               NaN       3052.0                NaN               NaN
# 2               NaN     177861.0                NaN             False
# 3               NaN       5300.0                0.0             False
# 4               NaN       9404.0                NaN               NaN
#
#    GarageSpaces     HighSchoolDistrict PostalCode BuyerOfficeName.1  \
# 0           2.0  Covina Valley Unified      91722               NaN
# 1           NaN                    NaN      92025               NaN
# 2           NaN                    NaN      90067               NaN
# 3           3.0     Capistrano Unified      92677               NaN
# 4           2.0                    NaN      91108               NaN
#
#    AssociationFee  LotSizeSquareFeet  MiddleOrJuniorSchoolDistrict  \
# 0             0.0                NaN                           NaN
# 1             0.0                NaN                           NaN
# 2          2105.0           177861.0                           NaN
# 3           254.0             5300.0                           NaN
# 4             NaN             9404.0                           NaN
#
#                UnparsedAddress.1
# 0                1045 N Azusa 61
# 1                            NaN
# 2  2220 Avenue Of The Stars 2704
# 3                   16 Palisades
# 4              1615 Waverly Road

# %%
sold.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'OriginatingSystemName', 'OriginatingSystemSubName',
#        'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'latfilled',
#        'lonfilled'],
#       dtype='object')

# %%
sold.shape
sold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591733 entries, 0 to 591732
# Data columns (total 84 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   BuyerAgentAOR                 520175 non-null  object
#  1   ListAgentAOR                  523685 non-null  object
#  2   Flooring                      347801 non-null  object
#  3   ViewYN                        532453 non-null  object
#  4   WaterfrontYN                  323 non-null     object
#  5   BasementYN                    9760 non-null    object
#  6   PoolPrivateYN                 517524 non-null  object
#  7   OriginalListPrice             590013 non-null  float64
#  8   ListingKey                    591733 non-null  int64
#  9   ListAgentEmail                547714 non-null  object
#  10  CloseDate                     591733 non-null  object
#  11  ClosePrice                    591726 non-null  float64
#  12  ListAgentFirstName            588300 non-null  object
#  13  ListAgentLastName             591673 non-null  object
#  14  Latitude                      572703 non-null  float64
#  15  Longitude                     572875 non-null  float64
#  16  UnparsedAddress               590829 non-null  object
#  17  PropertyType                  591733 non-null  object
#  18  LivingArea                    549951 non-null  float64
#  19  ListPrice                     590823 non-null  float64
#  20  DaysOnMarket                  591733 non-null  int64
#  21  ListOfficeName                591733 non-null  object
#  22  BuyerOfficeName               584405 non-null  object
#  23  CoListOfficeName              127030 non-null  object
#  24  ListAgentFullName             591573 non-null  object
#  25  CoListAgentFirstName          122325 non-null  object
#  26  CoListAgentLastName           122577 non-null  object
#  27  BuyerAgentMlsId               589901 non-null  object
#  28  BuyerAgentFirstName           589111 non-null  object
#  29  BuyerAgentLastName            591397 non-null  object
#  30  FireplacesTotal               0 non-null       float64
#  31  AssociationFeeFrequency       174903 non-null  object
#  32  AboveGradeFinishedArea        0 non-null       float64
#  33  ListingKeyNumeric             591733 non-null  int64
#  34  MLSAreaMajor                  526654 non-null  object
#  35  TaxAnnualAmount               2511 non-null    float64
#  36  CountyOrParish                591733 non-null  object
#  37  MlsStatus                     591733 non-null  object
#  38  ElementarySchool              65619 non-null   object
#  39  AttachedGarageYN              427674 non-null  object
#  40  ParkingTotal                  573049 non-null  float64
#  41  BuilderName                   22615 non-null   object
#  42  PropertySubType               546343 non-null  object
#  43  LotSizeAcres                  535701 non-null  float64
#  44  SubdivisionName               208746 non-null  object
#  45  BuyerOfficeAOR                566196 non-null  object
#  46  YearBuilt                     566783 non-null  float64
#  47  StreetNumberNumeric           590267 non-null  float64
#  48  ListingId                     591733 non-null  object
#  49  BathroomsTotalInteger         564309 non-null  float64
#  50  City                          591293 non-null  object
#  51  TaxYear                       368 non-null     float64
#  52  BuildingAreaTotal             76682 non-null   float64
#  53  BedroomsTotal                 552324 non-null  float64
#  54  ContractStatusChangeDate      591021 non-null  object
#  55  ElementarySchoolDistrict      0 non-null       float64
#  56  CoBuyerAgentFirstName         48058 non-null   object
#  57  PurchaseContractDate          579902 non-null  object
#  58  ListingContractDate           591650 non-null  object
#  59  BelowGradeFinishedArea        2591 non-null    float64
#  60  BusinessType                  1634 non-null    object
#  61  StateOrProvince               591733 non-null  object
#  62  CoveredSpaces                 0 non-null       float64
#  63  MiddleOrJuniorSchool          66065 non-null   object
#  64  FireplaceYN                   539989 non-null  object
#  65  Stories                       473288 non-null  float64
#  66  HighSchool                    86105 non-null   object
#  67  Levels                        510381 non-null  object
#  68  LotSizeDimensions             31046 non-null   object
#  69  LotSizeArea                   537570 non-null  float64
#  70  MainLevelBedrooms             313909 non-null  float64
#  71  NewConstructionYN             521478 non-null  object
#  72  GarageSpaces                  515952 non-null  float64
#  73  HighSchoolDistrict            394330 non-null  object
#  74  PostalCode                    591568 non-null  object
#  75  AssociationFee                408289 non-null  float64
#  76  LotSizeSquareFeet             537111 non-null  float64
#  77  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  78  OriginatingSystemName         60627 non-null   object
#  79  OriginatingSystemSubName      60627 non-null   object
#  80  BuyerAgencyCompensationType   67747 non-null   object
#  81  BuyerAgencyCompensation       67780 non-null   float64
#  82  latfilled                     95793 non-null   object
#  83  lonfilled                     95793 non-null   object
# dtypes: float64(28), int64(3), object(53)
# memory usage: 379.2+ MB

# %%
sold['PropertyType'].value_counts()
# Out:
# PropertyType
# Residential            397603
# ResidentialLease       135617
# Land                    19345
# ManufacturedInPark      16082
# ResidentialIncome       15865
# CommercialSale           3714
# CommercialLease          3104
# BusinessOpportunity       403
# Name: count, dtype: int64

# %% [markdown]
# ### Separate market analysis fields from metadata fields
# I separated the high-missing fields into two groups:
# - 1. market analysis fields: describe property, pricing, time, and location characteristics, and
# - 2. metadata/transactional fields: mainly capture agent, office, compensation, or duplicate system-related information.
#
# This helps avoid mixing analytically useful but sparse property features with administrative fields that are less relevant for market analysis.

# %%
sold_market_fields = [
    'Flooring', 'ViewYN', 'WaterfrontYN', 'BasementYN', 'PoolPrivateYN',
    'OriginalListPrice', 'CloseDate', 'ClosePrice', 'Latitude', 'Longitude',
    'UnparsedAddress', 'PropertyType', 'LivingArea', 'ListPrice',
    'DaysOnMarket', 'FireplacesTotal', 'AssociationFeeFrequency',
    'AboveGradeFinishedArea', 'MLSAreaMajor', 'TaxAnnualAmount',
    'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
    'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
    'SubdivisionName', 'YearBuilt', 'BathroomsTotalInteger', 'City',
    'TaxYear', 'BuildingAreaTotal', 'BedroomsTotal',
    'ContractStatusChangeDate', 'ElementarySchoolDistrict',
    'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
    'BusinessType', 'StateOrProvince', 'CoveredSpaces',
    'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
    'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
    'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
    'AssociationFee', 'LotSizeSquareFeet'
]

sold_metadata_fields = [
    'BuyerAgentAOR', 'ListAgentAOR', 'ListingKey', 'ListAgentEmail',
    'ListAgentFirstName', 'ListAgentLastName', 'ListOfficeName',
    'BuyerOfficeName', 'CoListOfficeName', 'ListAgentFullName',
    'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId',
    'BuyerAgentFirstName', 'BuyerAgentLastName', 'ListingKeyNumeric',
    'BuyerOfficeAOR', 'StreetNumberNumeric', 'ListingId',
    'CoBuyerAgentFirstName', 'MiddleOrJuniorSchoolDistrict',
    'OriginatingSystemName', 'OriginatingSystemSubName',
    'BuyerAgencyCompensationType', 'BuyerAgencyCompensation',
    'latfilled', 'lonfilled'
]

sold_other_fields = [col for col in sold.columns if col not in sold_market_fields + sold_metadata_fields]

# %%
sold_other_fields
# Out:
# []

# %%
len(sold_metadata_fields)
# Out:
# 27

# %%
len(sold_market_fields)
# Out:
# 57

# %% [markdown]
# ## Missing Value Analysis
# - count each columns and sum all the missing values
# - calculate the missing values ratios
# - if proportion > p then treat as high missing col
# - flag columns with >90% missing values

# %%
# highmissing threshold
p_high = 0.5
p_very_high = 0.9

sold_missing_summary = pd.DataFrame({
    'missing_count': sold.isna().sum(),
    'missing_ratio': sold.isna().mean()
}).sort_values('missing_ratio', ascending=False)

sold_high_missing_summary = sold_missing_summary[sold_missing_summary['missing_ratio'] > p_high]

sold_high_missing_summary['very_high_missing_flag'] = (sold_high_missing_summary['missing_ratio'] > p_very_high).astype(int)

sold_high_missing_summary
# Out:
# /var/folders/fb/y3cbnxzj3rs43kpb74nk2f0r0000gn/T/ipykernel_13010/2403980244.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sold_high_missing_summary['very_high_missing_flag'] = (sold_high_missing_summary['missing_ratio'] > p_very_high).astype(int)
#                               missing_count  missing_ratio  \
# AboveGradeFinishedArea               591733       1.000000
# FireplacesTotal                      591733       1.000000
# ElementarySchoolDistrict             591733       1.000000
# CoveredSpaces                        591733       1.000000
# MiddleOrJuniorSchoolDistrict         591733       1.000000
# WaterfrontYN                         591410       0.999454
# TaxYear                              591365       0.999378
# BusinessType                         590099       0.997239
# TaxAnnualAmount                      589222       0.995757
# BelowGradeFinishedArea               589142       0.995621
# BasementYN                           581973       0.983506
# BuilderName                          569118       0.961782
# LotSizeDimensions                    560687       0.947534
# CoBuyerAgentFirstName                543675       0.918784
# OriginatingSystemName                531106       0.897543
# OriginatingSystemSubName             531106       0.897543
# ElementarySchool                     526114       0.889107
# MiddleOrJuniorSchool                 525668       0.888353
# BuyerAgencyCompensationType          523986       0.885511
# BuyerAgencyCompensation              523953       0.885455
# BuildingAreaTotal                    515051       0.870411
# HighSchool                           505628       0.854487
# lonfilled                            495940       0.838114
# latfilled                            495940       0.838114
# CoListAgentFirstName                 469408       0.793277
# CoListAgentLastName                  469156       0.792851
# CoListOfficeName                     464703       0.785325
# AssociationFeeFrequency              416830       0.704422
# SubdivisionName                      382987       0.647229
#
#                               very_high_missing_flag
# AboveGradeFinishedArea                             1
# FireplacesTotal                                    1
# ElementarySchoolDistrict                           1
# CoveredSpaces                                      1
# MiddleOrJuniorSchoolDistrict                       1
# WaterfrontYN                                       1
# TaxYear                                            1
# BusinessType                                       1
# TaxAnnualAmount                                    1
# BelowGradeFinishedArea                             1
# BasementYN                                         1
# BuilderName                                        1
# LotSizeDimensions                                  1
# CoBuyerAgentFirstName                              1
# OriginatingSystemName                              0
# OriginatingSystemSubName                           0
# ElementarySchool                                   0
# MiddleOrJuniorSchool                               0
# BuyerAgencyCompensationType                        0
# BuyerAgencyCompensation                            0
# BuildingAreaTotal                                  0
# HighSchool                                         0
# lonfilled                                          0
# latfilled                                          0
# CoListAgentFirstName                               0
# CoListAgentLastName                                0
# CoListOfficeName                                   0
# AssociationFeeFrequency                            0
# SubdivisionName                                    0

# %% [markdown]
# ### Decide which columns to drop and retain

# %%
# keep fields that are core to market analysis, even if they have high missing ratio.
sold_retain = [
    'ClosePrice', 'CloseDate', 'OriginalListPrice', 'ListPrice',
    'DaysOnMarket', 'LivingArea', 'LotSizeAcres', 'BedroomsTotal',
    'BathroomsTotalInteger', 'YearBuilt', 'City', 'PostalCode',
    'CountyOrParish', 'StateOrProvince', 'Latitude', 'Longitude',
    'PropertyType', 'PropertySubType', 'MlsStatus',
    'ListingContractDate', 'PurchaseContractDate', 'SubdivisionName'
]
# fields that are not core to market analysis we will consider dropping or use for advanced analysis, depending on the missing ratio and the importance of the field.

sold_optional = [
    'AssociationFeeFrequency', 'BuildingAreaTotal', 'HighSchool',
    'ElementarySchool', 'MiddleOrJuniorSchool', 'BuilderName',
    'LotSizeDimensions', 'TaxAnnualAmount', 'TaxYear',
    'FireplaceYN', 'GarageSpaces', 'ParkingTotal', 'Stories',
    'Levels', 'MainLevelBedrooms', 'AttachedGarageYN', 'AssociationFee'
]

# fields that are not core to market analysis and have very high missing ratio, we will drop them
sold_drop = [
    'AboveGradeFinishedArea', 'FireplacesTotal', 'ElementarySchoolDistrict',
    'CoveredSpaces', 'MiddleOrJuniorSchoolDistrict', 'WaterfrontYN',
    'BusinessType', 'BelowGradeFinishedArea', 'BasementYN',
    'CoBuyerAgentFirstName', 'OriginatingSystemName',
    'OriginatingSystemSubName', 'BuyerAgencyCompensationType',
    'BuyerAgencyCompensation', 'lonfilled', 'latfilled',
    'CoListAgentFirstName', 'CoListAgentLastName', 'CoListOfficeName'
]


sold_cleaned = sold.drop(columns=sold_drop)

# %% [markdown]
# ## Numerical Distribution Review
# Analysis the distribution of key numeric fields include
# ClosePrice, ListPrice, OriginalListPrice, LivingArea,
# LotSizeAcres, BedroomsTotal, BathroomsTotalInteger, DaysOnMarket, and YearBuilt.
#
# For each field, generate histograms, boxplots, and percentile summaries, and identify extreme outliers for later handling.

# %%
# create a list of numeric fields to analyze for outliers
sold_numeric_fields = ['ClosePrice','ListPrice','OriginalListPrice','LivingArea','LotSizeAcres','BedroomsTotal','BathroomsTotalInteger','DaysOnMarket','YearBuilt']

sold_outlier_summary = []

for col in sold_numeric_fields:
    # define which fields to log-transform for better visualization
    log_fields = ['ClosePrice','ListPrice','OriginalListPrice','LivingArea','LotSizeAcres','DaysOnMarket']
    raw_fields = ['BedroomsTotal','BathroomsTotalInteger','YearBuilt']

    s = pd.to_numeric(sold[col], errors='coerce').dropna()

    print(f"\n===== {col} =====")

    percentile_summary = s.describe(percentiles=[0.01,0.05,0.25,0.5,0.75,0.95,0.99])
    print(percentile_summary.apply(lambda x: f'{x:,.2f}'))

    # calculate IQR and outlier thresholds
    q1 = s.quantile(0.25)
    q3 = s.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # define the extreme outlier thresholds
    extreme_lower = q1 - 3 * iqr
    extreme_upper = q3 + 3 * iqr

    outliers = s[(s < lower_bound) | (s > upper_bound)]
    extreme_outliers = s[(s < extreme_lower) | (s > extreme_upper)]

    sold_outlier_summary.append({
        'field': col,
        'count': len(s),
        'missing_count': listing[col].isna().sum(),
        'missing_ratio': listing[col].isna().mean(),
        'min': s.min(),
        'p1': s.quantile(0.01),
        'p5': s.quantile(0.05),
        'p25': q1,
        'p50': s.quantile(0.50),
        'p75': q3,
        'p95': s.quantile(0.95),
        'p99': s.quantile(0.99),
        'max': s.max(),
        'iqr': iqr,
        'outlier_count': len(outliers),
        'outlier_ratio': len(outliers) / len(s),
        'extreme_outlier_count': len(extreme_outliers),
        'extreme_outlier_ratio': len(extreme_outliers) / len(s),
        'lower_bound': lower_bound,
        'upper_bound': upper_bound,
        'extreme_lower_bound': extreme_lower,
        'extreme_upper_bound': extreme_upper
    })
    
    plt.figure(figsize=(10, 2.5))
    
    if col in log_fields:
        sns.boxplot(x=np.log1p(s))
        plt.xlabel(f'log(1 + {col})')
        plt.title(f'Boxplot of log-transformed {col}')

        plt.figure(figsize=(10, 4))
        sns.histplot(x=np.log1p(s), bins=30, kde=True)
        plt.title(f'Histogram of log-transformed {col}')
        plt.xlabel(f'log(1 + {col})')
        plt.ylabel('Frequency')

    else:
        sns.boxplot(x=s)
        plt.xlabel(col)
        plt.title(f'Boxplot of {col}')

        plt.figure(figsize=(10, 4))
        sns.histplot(s, bins=30, kde=True)
        plt.title(f'Histogram of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')

    
    plt.show()

sold_outlier_summary = pd.DataFrame(sold_outlier_summary)
sold_outlier_summary
# Out:
# ===== ClosePrice =====
# count        591,726.00
# mean         874,014.73
# std        5,229,021.13
# min                0.00
# 1%             1,750.00
# 5%             2,695.00
# 25%           52,500.00
# 50%          629,727.50
# 75%        1,070,000.00
# 95%        2,500,000.00
# 99%        4,995,000.00
# max      989,500,000.00
# Name: ClosePrice, dtype: object
# ===== ListPrice =====
# count        590,823.00
# mean         839,973.29
# std        1,275,509.04
# min                0.00
# 1%             1,795.00
# 5%             2,700.00
# 25%           62,500.00
# 50%          629,900.00
# 75%        1,050,000.00
# 95%        2,498,000.00
# 99%        4,999,000.00
# max      137,500,000.00
# Name: ListPrice, dtype: object
# ===== OriginalListPrice =====
# count          590,013.00
# mean           905,987.16
# std          5,742,312.61
# min                  0.00
# 1%               1,800.00
# 5%               2,750.00
# 25%             65,000.00
# 50%            639,990.00
# 75%          1,089,000.00
# 95%          2,549,000.00
# 99%          5,298,000.00
# max      1,390,000,000.00
# Name: OriginalListPrice, dtype: object
# ===== LivingArea =====
# count        549,951.00
# mean           3,495.37
# std        1,226,085.59
# min                0.00
# 1%               480.00
# 5%               734.00
# 25%            1,183.00
# 50%            1,579.00
# 75%            2,150.00
# 95%            3,537.00
# 99%            5,464.50
# max      909,090,909.00
# Name: LivingArea, dtype: object
# ===== LotSizeAcres =====
# count        535,701.00
# mean             762.92
# std          506,069.44
# min                0.00
# 1%                 0.00
# 5%                 0.03
# 25%                0.12
# 50%                0.17
# 75%                0.30
# 95%                3.58
# 99%               15.85
# max      370,260,000.00
# Name: LotSizeAcres, dtype: object
# ===== BedroomsTotal =====
# count    552,324.00
# mean           3.08
# std            1.40
# min            0.00
# 1%             1.00
# 5%             1.00
# 25%            2.00
# 50%            3.00
# 75%            4.00
# 95%            5.00
# 99%            6.00
# max          123.00
# Name: BedroomsTotal, dtype: object
# ===== BathroomsTotalInteger =====
# count    564,309.00
# mean           2.45
# std            1.42
# min            0.00
# 1%             0.00
# 5%             1.00
# 25%            2.00
# 50%            2.00
# 75%            3.00
# 95%            4.00
# 99%            6.00
# max          175.00
# Name: BathroomsTotalInteger, dtype: object
# ===== DaysOnMarket =====
# count    591,733.00
# mean          43.29
# std           69.84
# min         -288.00
# 1%             0.00
# 5%             2.00
# 25%            9.00
# 50%           22.00
# 75%           54.00
# 95%          147.00
# 99%          290.00
# max       12,430.00
# Name: DaysOnMarket, dtype: object
# /Users/huangyihua/miniconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/huangyihua/miniconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/huangyihua/miniconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/huangyihua/miniconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ===== YearBuilt =====
# count    566,783.00
# mean       1,978.10
# std           27.09
# min        1,776.00
# 1%         1,911.00
# 5%         1,927.00
# 25%        1,960.00
# 50%        1,979.00
# 75%        1,999.00
# 95%        2,022.00
# 99%        2,025.00
# max        2,026.00
# Name: YearBuilt, dtype: object
#                    field   count  missing_count  missing_ratio     min  \
# 0             ClosePrice  591726         613920       0.719750     0.0
# 1              ListPrice  590823           2137       0.002505     0.0
# 2      OriginalListPrice  590013           3322       0.003895     0.0
# 3             LivingArea  549951         106478       0.124833     0.0
# 4           LotSizeAcres  535701          81425       0.095461     0.0
# 5          BedroomsTotal  552324         103082       0.120852     0.0
# 6  BathroomsTotalInteger  564309          69978       0.082041     0.0
# 7           DaysOnMarket  591733              0       0.000000  -288.0
# 8              YearBuilt  566783          69474       0.081450  1776.0
#
#        p1         p5         p25          p50           p75           p95  \
# 0  1750.0  2695.0000  52500.0000  629727.5000  1.070000e+06  2.500000e+06
# 1  1795.0  2700.0000  62500.0000  629900.0000  1.050000e+06  2.498000e+06
# 2  1800.0  2750.0000  65000.0000  639990.0000  1.089000e+06  2.549000e+06
# 3   480.0   734.0000   1183.0000    1579.0000  2.150000e+03  3.537000e+03
# 4     0.0     0.0275      0.1194       0.1677  2.985000e-01  3.581800e+00
# 5     1.0     1.0000      2.0000       3.0000  4.000000e+00  5.000000e+00
# 6     0.0     1.0000      2.0000       2.0000  3.000000e+00  4.000000e+00
# 7     0.0     2.0000      9.0000      22.0000  5.400000e+01  1.470000e+02
# 8  1911.0  1927.0000   1960.0000    1979.0000  1.999000e+03  2.022000e+03
#
#           p99           max           iqr  outlier_count  outlier_ratio  \
# 0  4995000.00  9.895000e+08  1.017500e+06          27498       0.046471
# 1  4999000.00  1.375000e+08  9.875000e+05          28229       0.047779
# 2  5298000.00  1.390000e+09  1.024000e+06          27797       0.047113
# 3     5464.50  9.090909e+08  9.670000e+02          25746       0.046815
# 4       15.85  3.702600e+08  1.791000e-01          85053       0.158770
# 5        6.00  1.230000e+02  2.000000e+00           2069       0.003746
# 6        6.00  1.750000e+02  1.000000e+00          37325       0.066143
# 7      290.00  1.243000e+04  4.500000e+01          43862       0.074125
# 8     2025.00  2.026000e+03  3.900000e+01           1525       0.002691
#
#    extreme_outlier_count  extreme_outlier_ratio   lower_bound   upper_bound  \
# 0                   9388               0.015865 -1.473750e+06  2.596250e+06
# 1                   9698               0.016414 -1.418750e+06  2.531250e+06
# 2                  10239               0.017354 -1.471000e+06  2.625000e+06
# 3                   7350               0.013365 -2.675000e+02  3.600500e+03
# 4                  70055               0.130773 -1.492500e-01  5.671500e-01
# 5                    853               0.001544 -1.000000e+00  7.000000e+00
# 6                   4599               0.008150  5.000000e-01  4.500000e+00
# 7                  16307               0.027558 -5.850000e+01  1.215000e+02
# 8                     23               0.000041  1.901500e+03  2.057500e+03
#
#    extreme_lower_bound  extreme_upper_bound
# 0        -3.000000e+06         4.122500e+06
# 1        -2.900000e+06         4.012500e+06
# 2        -3.007000e+06         4.161000e+06
# 3        -1.718000e+03         5.051000e+03
# 4        -4.179000e-01         8.358000e-01
# 5        -4.000000e+00         1.000000e+01
# 6        -1.000000e+00         6.000000e+00
# 7        -1.260000e+02         1.890000e+02
# 8         1.843000e+03         2.116000e+03
